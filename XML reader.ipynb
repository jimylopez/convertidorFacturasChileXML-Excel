# %% [markdown]
# # Script para leer archivos XML de Loreal más abajo

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
archivo = open('D:/Google Drive/LA BANQUETA/PEDIDOS PRODUCTOS/FACTURAS/SC79906790-0SC033F0000020747.xml','r')
factura = archivo.read()
archivo.close()
print(factura)

# %%
print(texto)

# %%
from xml.etree import cElementTree as ET
import pandas as pd

path = 'D:/Google Drive/LA BANQUETA/PEDIDOS PRODUCTOS/FACTURAS/'
file = input("Nombre del archivo: ")
archivo = open(path+file,'r')
factura = archivo.readlines()
archivo.close()

texto = ""
folio=0
folios = []
fecha = ''
fechas = []
proveedor = ''
proveedores = []
eans = []
codInterno = []
items = []
cantidad = []
precios = []
totSinIva = 0
totSinIvas = []
iva = 0
ivas =[]
totConIva = 0
totConIvas = []

def cierres():
    folios.append(folio)
    proveedores.append(proveedor)
    fechas.append(fecha)
    totSinIvas.append(totSinIva)
    ivas.append(iva)
    totConIvas.append(totConIva)
    
for i in factura:
    i=i.lstrip()
    if i[0:7] == "<Folio>":
        i= i.replace("<Folio>","")
        i= i.replace("</Folio>","")
        i = i.replace("\n","")
        folio=i
        cierres()
        i = i + '\n'
    if i[0:9] == "<FchEmis>":
        i = i.replace("<FchEmis>", "")
        i = i.replace("</FchEmis>", "")
        i = i.replace("\n", "")
        fecha = i
        i = i + '\n'
        i = i + '\n'
    if i[0:8] == "<RznSoc>":
        i= i.replace("<RznSoc>","")
        i= i.replace("</RznSoc>","")
        i = i.replace("\n","")
        proveedor=i
        i = i + '\n'
    
    if i[0:11] == "<VlrCodigo>":
        i = i.replace("<VlrCodigo>","")
        i = i.replace("</VlrCodigo>","")
        i = i.replace("\n","")
        if len(i) <=8:
            codInterno.append(i)
        else: 
            eans.append(i)
        i = i + '\n'
    if i[0:9] == "<NmbItem>":
        i = i.replace("<NmbItem>","")
        i = i.replace("</NmbItem>","")
        i = i.replace("\n","")
        items.append(i)
        i = i + '\n'
    if i[0:9] == "<QtyItem>":
        i = i.replace("<QtyItem>","")
        i = i.replace("</QtyItem>","")
        i = i.replace("\n","")
        cantidad.append(int(i))
        i = i + '\n'
    if i[0:9] == "<PrcItem>":
        i = i.replace("<PrcItem>","")
        i = i.replace("</PrcItem>","")
        i = i.replace("\n","")
        precios.append(int(i))
        i = i + '\n'

    texto += i
    
data = pd.DataFrame(
    {
        "EAN" : eans,
        "CodigoInterno" : codInterno,
        "Descripción" : items,
        "Cantidad" : cantidad,
        "Precio" : precios,
        "Venta":0,
        "Fecha" : fecha,
        "Factura": folio,
        "Proveedor":proveedor
    }
)
data["Venta"] = data["Precio"]*data["Cantidad"]
data.head(15)

#data.to_excel(path+'{} {} - Factura {}.xlsx'.format(fecha,proveedor,folio))

# %%
# versión ok
from xml.etree import cElementTree as ET
import pandas as pd

path = 'D:/Google Drive/LA BANQUETA/PEDIDOS PRODUCTOS/FACTURAS/'
file = input("Nombre del archivo: ")
archivo = open(path+file,'r')
factura = archivo.readlines()
archivo.close()

texto = ""
folio=0
folios = []
fecha = ''
fechas = []
proveedor = ''
proveedores = []
eans = []
codInterno = []
items = []
cantidad = []
precios = []
totSinIva = 0
totSinIvas = []
iva = 0
ivas =[]
totConIva = 0
totConIvas = []

def cierres():
    folios.append(folio)
    proveedores.append(proveedor)
    fechas.append(fecha)
    totSinIvas.append(totSinIva)
    ivas.append(iva)
    totConIvas.append(totConIva)
    
for i in factura:
    i=i.lstrip()
    if i[0:7] == "<Folio>":
        i= i.replace("<Folio>","")
        i= i.replace("</Folio>","")
        i = i.replace("\n","")
        folio=i
        cierres()
        i = i + '\n'
    if i[0:9] == "<FchEmis>":
        i = i.replace("<FchEmis>", "")
        i = i.replace("</FchEmis>", "")
        i = i.replace("\n", "")
        fecha = i
        i = i + '\n'
        i = i + '\n'
    if i[0:8] == "<RznSoc>":
        i= i.replace("<RznSoc>","")
        i= i.replace("</RznSoc>","")
        i = i.replace("\n","")
        proveedor=i
        i = i + '\n'
    
    if i[0:11] == "<VlrCodigo>":
        i = i.replace("<VlrCodigo>","")
        i = i.replace("</VlrCodigo>","")
        i = i.replace("\n","")
        if len(i) <=8:
            codInterno.append(i)
        else: 
            eans.append(i)
        i = i + '\n'
    if i[0:9] == "<NmbItem>":
        i = i.replace("<NmbItem>","")
        i = i.replace("</NmbItem>","")
        i = i.replace("\n","")
        items.append(i)
        i = i + '\n'
    if i[0:9] == "<QtyItem>":
        i = i.replace("<QtyItem>","")
        i = i.replace("</QtyItem>","")
        i = i.replace("\n","")
        cantidad.append(int(i))
        i = i + '\n'
    if i[0:9] == "<PrcItem>":
        i = i.replace("<PrcItem>","")
        i = i.replace("</PrcItem>","")
        i = i.replace("\n","")
        precios.append(int(i))
        i = i + '\n'

    texto += i
    
data = pd.DataFrame(
    {
        "EAN" : eans,
        "CodigoInterno" : codInterno,
        "Descripción" : items,
        "Cantidad" : cantidad,
        "Precio" : precios,
        "Venta":0,
        "Fecha" : fecha,
        "Factura": folio,
        "Proveedor":proveedor
    }
)
data["Venta"] = data["Precio"]*data["Cantidad"]
data.head(15)

#data.to_excel(path+'{} {} - Factura {}.xlsx'.format(fecha,proveedor,folio))

# %%
# version de prueba casi ok

from xml.etree import cElementTree as ET
import pandas as pd

path = 'D:/Google Drive/LA BANQUETA/PEDIDOS PRODUCTOS/FACTURAS/'
file = 'DTE_DOWN764097332020-07-03.xml' #input("Nombre del archivo: ")
archivo = open(path+file,'r')
#archivo = open(path+'DTE_DOWN764097332020-07-03.xml','r')
factura = archivo.readlines()
archivo.close()

texto = ""
rut = 0
ruts = []
folio=0
folios = []
fecha = ''
fechas = []
proveedor = ''
proveedores = []
eans = []
codInterno = []
items = []
unidadMedida = ' '
unidadMedidas = []
cantidad = 1.00
cantidades = []
precio = 0
precios = []
totSinIva = 0
totSinIvas = []
descuento = 0
descuentos = []
iva = 0
ivas =[]
excento = 0
excentos = []
totConIva = 0
totConIvas = []

def cierres():
    ruts.append(rut)
    folios.append(int(folio))
    proveedores.append(proveedor)
    fechas.append(fecha)
    totSinIvas.append(float(totSinIva))
    descuentos.append(descuento)
    ivas.append(float(iva))
    excentos.append(excento)
    totConIvas.append(float(totConIva))
    cantidades.append(cantidad)
    unidadMedidas.append(unidadMedida)
    precios.append(float(precio))

def blank():
    cantidad = 1.00
    totSinIva = 0
    totConIva = 0
    iva = 0
    excento = 0
    precio = ''
    descuento = 0
    
    
    
for i in factura:
    i=i.lstrip()
    
    if i[0:11] == "<RUTEmisor>":
        i= i.replace("<RUTEmisor>","")
        i= i.replace("</RUTEmisor>","")
        i = i.replace("\n","")
        rut=i
    if i[0:7] == "<Folio>":
        i= i.replace("<Folio>","")
        i= i.replace("</Folio>","")
        i = i.replace("\n","")
        folio=i
        i = i + '\n'
    if i[0:9] == "<FchEmis>":
        i = i.replace("<FchEmis>", "")
        i = i.replace("</FchEmis>", "")
        i = i.replace("\n", "")
        fecha = i
    if i[0:8] == "<RznSoc>":
        i= i.replace("<RznSoc>","")
        i= i.replace("</RznSoc>","")
        i = i.replace("\n","")
        proveedor=i
    if i[0:10] == "<MntTotal>":
        i= i.replace("<MntTotal>","")
        i= i.replace("</MntTotal>","")
        i = i.replace("\n","")
        totConIva=i
    if i[0:9] == "<MntNeto>":
        i= i.replace("<MntNeto>","")
        i= i.replace("</MntNeto>","")
        i = i.replace("\n","")
        if i == '':
            totSinIva = 0
        else:
            totSinIva=i
    if i[0:9] == "<ValorDR>":
        i= i.replace("<ValorDR>","")
        i= i.replace("</ValorDR>","")
        i = i.replace("\n","")
        descuento = i
        i = i + '\n'
    if i[0:5] == "<IVA>":
        i= i.replace("<IVA>","")
        i= i.replace("</IVA>","")
        i = i.replace("\n","")
        if i == '':
            iva = 0
        else:
            iva=i
    if i[0:8] == "<MntExe>":
        i= i.replace("<MntExe>","")
        i= i.replace("</MntExe>","")
        i = i.replace("\n","")
        if i == '':
            excento = 0
        else:
            excento=i
        
        
        
    # caso loreal
    '''if i[0:11] == "<VlrCodigo>":
        i = i.replace("<VlrCodigo>","")
        i = i.replace("</VlrCodigo>","")
        i = i.replace("\n","")
        if len(i) <=8:
            codInterno.append(i)
        else: 
            eans.append(i)
        cierres()'''
    
    
    if i[0:9] == "<QtyItem>":
        i = i.replace("<QtyItem>","")
        i = i.replace("</QtyItem>","")
        i = i.replace("\n","")
        if float(i) >= 0.0:
            cantidad = i
        else:
            cantidad = 1
        cantidad = 1
    if i[0:10] == "<UnmdItem>":
        i = i.replace("<UnmdItem>","")
        i = i.replace("</UnmdItem>","")
        i = i.replace("\n","")
        if i == '':
            unidadMedida = ''
        else:
            unidadMedida = i
    if i[0:9] == "<PrcItem>":
        i = i.replace("<PrcItem>","")
        i = i.replace("</PrcItem>","")
        i = i.replace("\n","")
        if i == '':
            precio = 0
        else:
            precio = i
    if i[0:9] == "<NmbItem>":
        i = i.replace("<NmbItem>","")
        i = i.replace("</NmbItem>","")
        i = i.replace("\n","")
        items.append(i)
        cierres()
        blank()
        
    texto += i
    
    
data = pd.DataFrame(
    {
        #"EAN" : eans,
        #"CodigoInterno" : codInterno,
        "RUT": ruts,
        "Razón Social":proveedores,
        "Fecha" : fechas,
        "Factura": folios,
        "Descripción" : items,
        #"Cantidad" : cantidades,
        #"Unidad Medida":unidadMedidas,
        #"Precio Item" : precios,
        "Descuento":descuentos,
        #"MontoFactSinIva": totSinIvas,
        #"IVA":ivas,
        #"Excento":excentos,
        #"MontoFactConIva": totConIvas
        
    }
)
#data["Monto Item"] = data["Precio Item"]*data["Cantidad"]
data.head(70)

#data.to_excel(path+'{} {} - Factura {}.xlsx'.format(fecha,proveedor,folio))

# %%
#test con while
from xml.etree import cElementTree as ET
import pandas as pd

path = 'D:/Google Drive/LA BANQUETA/PEDIDOS PRODUCTOS/FACTURAS/'
file = 'DTE_DOWN764097332020-07-03.xml' #input("Nombre del archivo: ")
archivo = open(path+file,'r')
#archivo = open(path+'DTE_DOWN764097332020-07-03.xml','r')
factura = archivo.readlines()
archivo.close()

texto = ""
rut = 0
ruts = []
folio=0
folios = []
fecha = ''
fechas = []
proveedor = ''
proveedores = []
eans = []
codInterno = []
items = []
unidadMedida = ' '
unidadMedidas = []
cantidad = 1.00
cantidades = []
precio = 0
precios = []
totSinIva = 0
totSinIvas = []
descuento = 0
descuentos = []
iva = 0
ivas =[]
excento = 0
excentos = []
totConIva = 0
totConIvas = []

def cierres():
    ruts.append(rut)
    folios.append(int(folio))
    proveedores.append(proveedor)
    fechas.append(fecha)
    totSinIvas.append(float(totSinIva))
    descuentos.append(descuento)
    ivas.append(float(iva))
    excentos.append(excento)
    totConIvas.append(float(totConIva))
    cantidades.append(cantidad)
    unidadMedidas.append(unidadMedida)
    precios.append(float(precio))

def blank():
    cantidad = 1.00
    totSinIva = 0
    totConIva = 0
    iva = 0
    excento = 0
    precio = ''
    descuento = 0
    
nfactura = 0    
    
for i in factura:
    i=i.lstrip()
    if i == "<TipoDTE>34</TipoDTE>":
        nfactura += 1
        while i != "<TipoDTE>34</TipoDTE>":
            if i[0:11] == "<RUTEmisor>":
                i= i.replace("<RUTEmisor>","")
                i= i.replace("</RUTEmisor>","")
                i = i.replace("\n","")
                rut=i
            if i[0:7] == "<Folio>":
                i= i.replace("<Folio>","")
                i= i.replace("</Folio>","")
                i = i.replace("\n","")
                folio=i
                i = i + '\n'
            if i[0:9] == "<FchEmis>":
                i = i.replace("<FchEmis>", "")
                i = i.replace("</FchEmis>", "")
                i = i.replace("\n", "")
                fecha = i
            if i[0:8] == "<RznSoc>":
                i= i.replace("<RznSoc>","")
                i= i.replace("</RznSoc>","")
                i = i.replace("\n","")
                proveedor=i
            if i[0:10] == "<MntTotal>":
                i= i.replace("<MntTotal>","")
                i= i.replace("</MntTotal>","")
                i = i.replace("\n","")
                totConIva=i
            if i[0:9] == "<MntNeto>":
                i= i.replace("<MntNeto>","")
                i= i.replace("</MntNeto>","")
                i = i.replace("\n","")
                if i == '':
                    totSinIva = 0
                else:
                    totSinIva=i
            if i[0:9] == "<ValorDR>":
                i= i.replace("<ValorDR>","")
                i= i.replace("</ValorDR>","")
                i = i.replace("\n","")
                descuento = i
                i = i + '\n'
            if i[0:5] == "<IVA>":
                i= i.replace("<IVA>","")
                i= i.replace("</IVA>","")
                i = i.replace("\n","")
                if i == '':
                    iva = 0
                else:
                    iva=i
            if i[0:8] == "<MntExe>":
                i= i.replace("<MntExe>","")
                i= i.replace("</MntExe>","")
                i = i.replace("\n","")
                if i == '':
                    excento = 0
                else:
                    excento=i
            
    
    
    
    
    
    
        
        
        
    # caso loreal
    '''if i[0:11] == "<VlrCodigo>":
        i = i.replace("<VlrCodigo>","")
        i = i.replace("</VlrCodigo>","")
        i = i.replace("\n","")
        if len(i) <=8:
            codInterno.append(i)
        else: 
            eans.append(i)
        cierres()'''
    
    
    if i[0:9] == "<QtyItem>":
        i = i.replace("<QtyItem>","")
        i = i.replace("</QtyItem>","")
        i = i.replace("\n","")
        if float(i) >= 0.0:
            cantidad = i
        else:
            cantidad = 1
        cantidad = 1
    if i[0:10] == "<UnmdItem>":
        i = i.replace("<UnmdItem>","")
        i = i.replace("</UnmdItem>","")
        i = i.replace("\n","")
        if i == '':
            unidadMedida = ''
        else:
            unidadMedida = i
    if i[0:9] == "<PrcItem>":
        i = i.replace("<PrcItem>","")
        i = i.replace("</PrcItem>","")
        i = i.replace("\n","")
        if i == '':
            precio = 0
        else:
            precio = i
    if i[0:9] == "<NmbItem>":
        i = i.replace("<NmbItem>","")
        i = i.replace("</NmbItem>","")
        i = i.replace("\n","")
        items.append(i)
        cierres()
        blank()
        
    texto += i
    
    
data = pd.DataFrame(
    {
        #"EAN" : eans,
        #"CodigoInterno" : codInterno,
        "RUT": ruts,
        "Razón Social":proveedores,
        "Fecha" : fechas,
        "Factura": folios,
        "Descripción" : items,
        #"Cantidad" : cantidades,
        #"Unidad Medida":unidadMedidas,
        #"Precio Item" : precios,
        "Descuento":descuentos,
        #"MontoFactSinIva": totSinIvas,
        #"IVA":ivas,
        #"Excento":excentos,
        #"MontoFactConIva": totConIvas
        
    }
)
#data["Monto Item"] = data["Precio Item"]*data["Cantidad"]
data.head(70)

#data.to_excel(path+'{} {} - Factura {}.xlsx'.format(fecha,proveedor,folio))

# %%
# probando readline de a 1
from xml.etree import cElementTree as ET
import pandas as pd

path = 'D:/Google Drive/LA BANQUETA/PEDIDOS PRODUCTOS/FACTURAS/'
file = 'DTE_DOWN764097332020-07-03.xml' #input("Nombre del archivo: ")
archivo = open(path+file,'r')


texto = ""
rut = ''
ruts = []
folio =''
folios = []
fecha = ''
fechas = []
proveedor = ''
proveedores = []
eans = []
codInterno = []
items = []
unidadMedida = ' '
unidadMedidas = []
cantidad = ''
cantidades = []
precio = ''
precios = []
totSinIva = ''
totSinIvas = []
iva = ''
ivas =[]
excento = ''
excentos = []
totConIva = ''
totConIvas = []

def creaFactura():
    ruts.append(rut)
    folios.append(int(folio))
    proveedores.append(proveedor)
    fechas.append(fecha)
    totSinIvas.append(float(totSinIva))
    ivas.append(float(iva))
    excentos.append(excento)
    totConIvas.append(float(totConIva))

def cierres():
    ruts.append(rut)
    folios.append(int(folio))
    proveedores.append(proveedor)
    fechas.append(fecha)
    totSinIvas.append(float(totSinIva))
    ivas.append(float(iva))
    excentos.append(excento)
    totConIvas.append(float(totConIva))
    cantidades.append(cantidad)
    unidadMedidas.append(unidadMedida)
    precios.append(float(precio))

def blank():
    cantidad = ''
    totSinIva = ''
    totConIva = ''
    iva = ''
    excento = ''
    precio = ''

i = ''
m = ''
l = ''
    
def nexti():
    i = archivo.readline()
    i = i.lstrip()
def nextm():
    m = archivo.readline()
    m = m.lstrip()
def nextl():
    l = archivo.readline()
    l = l.lstrip()
    

    
nextl()
while l != '</SetDTE>':
    nextm()
    if m != "<TipoDTE>34</TipoDTE>":
        nextm()
        l = m
    else:
        while m == "<TipoDTE>34</TipoDTE>":
            if i[0:7] == "<Folio>":
                i = i.replace("<Folio>","")
                i = i.replace("</Folio>","")
                i = i.replace("\n","")
                folio=i
                folios.append(folio)
            if i[0:10] == "</Totales>": #cierre de la 1era parte
                   # creaFactura()
                    nextm()    
            nexti()
            '''if i[0:9] == "<FchEmis>":
                    i = i.replace("<FchEmis>", "")
                    i = i.replace("</FchEmis>", "")
                    i = i.replace("\n", "")
                    fecha = i
                    nexti()
                if i[0:11] == "<RUTEmisor>":
                    i = i.replace("<RUTEmisor>","")
                    i = i.replace("</RUTEmisor>","")
                    i = i.replace("\n","")
                    rut=i
                    nexti()
                if i[0:8] == "<RznSoc>":
                    i = i.replace("<RznSoc>","")
                    i = i.replace("</RznSoc>","")
                    i = i.replace("\n","")
                    proveedor=i
                    nexti()
                if i[0:9] == "<MntNeto>":
                    i = i.replace("<MntNeto>","")
                    i = i.replace("</MntNeto>","")
                    i = i.replace("\n","")
                    totSinIva=i
                    nexti()
                if i[0:8] == "<MntExe>":
                    i = i.replace("<MntExe>","")
                    i = i.replace("</MntExe>","")
                    i = i.replace("\n","")
                    excento = i
                    nexti()
                if i[0:5] == "<IVA>":
                    i= i.replace("<IVA>","")
                    i= i.replace("</IVA>","")
                    i = i.replace("\n","")
                    iva = i
                    nexti()
                if i[0:10] == "<MntTotal>":
                    i = i.replace("<MntTotal>","")
                    i = i.replace("</MntTotal>","")
                    i = i.replace("\n","")
                    totConIva=i
                    nexti()
                if i[0:10] == "</Totales>": #cierre de la 1era parte
                    creaFactura()
                    nexti()    '''   
                
        
archivo.close()

print(folio)
          
        
'''items factura
            if i[0:9] == "<QtyItem>":
                i = i.replace("<QtyItem>","")
                i = i.replace("</QtyItem>","")
                i = i.replace("\n","")
                if float(i) >= 1:
                    cantidad = i
                else:
                    cantidad = 1
                nexti()
            if i[0:10] == "<UnmdItem>":
                i = i.replace("<UnmdItem>","")
                i = i.replace("</UnmdItem>","")
                i = i.replace("\n","")
                if i == '':
                    unidadMedida = ''
                else:
                    unidadMedida = i
            if i[0:9] == "<PrcItem>":
                i = i.replace("<PrcItem>","")
                i = i.replace("</PrcItem>","")
                i = i.replace("\n","")
                if i == '':
                    precio = 0
                else:
                    precio = i
            if i[0:9] == "<NmbItem>":
                i = i.replace("<NmbItem>","")
                i = i.replace("</NmbItem>","")
                i = i.replace("\n","")
                items.append(i)
                
                
        
                        
        
data = pd.DataFrame(
    {
        #"EAN" : eans,
        #"CodigoInterno" : codInterno,
       "RUT": ruts,
       # "Razón Social":proveedores,
       # "Fecha" : fechas,
       # "Factura": folios,
       # "Descripción" : items,
        #"Cantidad" : cantidades,
        #"Unidad Medida":unidadMedidas,
        #"Precio Item" : precios,
       # "Descuento":descuentos,
        #"MontoFactSinIva": totSinIvas,
        #"IVA":ivas,
        #"Excento":excentos,
        #"MontoFactConIva": totConIvas
        
    }
)
#data["Monto Item"] = data["Precio Item"]*data["Cantidad"]
data.head(70)      
    


'''
