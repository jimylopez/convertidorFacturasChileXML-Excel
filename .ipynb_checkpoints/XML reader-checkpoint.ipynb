# %% [markdown]
# # Script para leer archivos XML de Loreal más abajo

# %%
archivo = open('D:/Google Drive/LA BANQUETA/PEDIDOS PRODUCTOS/FACTURAS/2020-04-20 LOREAL - 2248028 - 33_3322480281587410044662.xml','r')
factura = archivo.read()
archivo.close()
print(factura)
# Out:
# <?xml version="1.0" encoding="ISO-8859-1"?>
# <EnvioDTE version="1.0" xmlns="http://www.sii.cl/SiiDte" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.sii.cl/SiiDte EnvioDTE_v10.xsd">
# <SetDTE ID="EDTE46735916D328634650">
# <Caratula version="1.0">
# <RutEmisor>79693930-3</RutEmisor>
# <RutEnvia>10586237-7</RutEnvia>
# <RutReceptor>76319854-5</RutReceptor>
# <FchResol>2006-01-05</FchResol>
# <NroResol>1</NroResol>
# <TmstFirmaEnv>2020-04-21T15:22:26</TmstFirmaEnv>
# <SubTotDTE>
# <TpoDTE>33</TpoDTE>
# <NroDTE>1</NroDTE>
# </SubTotDTE>
# </Caratula>
# <DTE version="1.0" xmlns="http://www.sii.cl/SiiDte">
# <Documento ID="S20200421T033F0002248191">
# 		<Encabezado>
# 			<IdDoc>
# 				<TipoDTE>33</TipoDTE>
# 				<Folio>2248191</Folio>
# 				<FchEmis>2020-04-21</FchEmis>
# 				<FchVenc>2020-06-20</FchVenc>
# 			</IdDoc>
# 			<Emisor>
# 				<RUTEmisor>79693930-3</RUTEmisor>
# 				<RznSoc>L OREAL CHILE S A</RznSoc>
# 				<GiroEmis>Distribucion productos cosmeticos y capilares</GiroEmis>
# 				<Acteco>513930</Acteco>
# 				<DirOrigen>Apoquindo 3885 piso 2</DirOrigen>
# 				<CmnaOrigen>LAS CONDES</CmnaOrigen>
# 				<CiudadOrigen>SANTIAGO</CiudadOrigen>
# 				<CdgVendedor>;;</CdgVendedor>
# 			</Emisor>
# 			<Receptor>
# 				<RUTRecep>76319854-5</RUTRecep>
# 				<CdgIntRecep>0000111946</CdgIntRecep>
# 				<RznSocRecep>SALONES DE BELLEZA LA BANQUETA LTDA</RznSocRecep>
# 				<GiroRecep>SALON DE BELLEZA</GiroRecep>
# 				<DirRecep>PRESIDENTE RIESCO 3160</DirRecep>
# 				<CmnaRecep>LAS CONDES</CmnaRecep>
# 				<CiudadRecep>SANTIAGO</CiudadRecep>
# 				<DirPostal>PRESIDENTE RIESCO 3160</DirPostal>
# 				<CmnaPostal>LAS CONDES</CmnaPostal>
# 			</Receptor>
# 			<Totales>
# 				<MntNeto>421955</MntNeto>
# 				<TasaIVA>19.00</TasaIVA>
# 				<IVA>80171</IVA>
# 				<MntTotal>502126</MntTotal>
# 			</Totales>
# 		</Encabezado>
# 		<Detalle>
# 			<NroLinDet>1</NroLinDet>
# 			<CdgItem>
# 				<TpoCodigo>INT1</TpoCodigo>
# 				<VlrCodigo>59451801</VlrCodigo>
# 			</CdgItem>
# 			<CdgItem>
# 				<TpoCodigo>EAN13</TpoCodigo>
# 				<VlrCodigo>743877066945</VlrCodigo>
# 			</CdgItem>
# 			<NmbItem>PROCESSING SOLUTION 1 LT</NmbItem>
# 			<QtyItem>3</QtyItem>
# 			<UnmdItem>UN</UnmdItem>
# 			<PrcItem>6790</PrcItem>
# 			<MontoItem>20370</MontoItem>
# 		</Detalle>
# 		<Detalle>
# 			<NroLinDet>2</NroLinDet>
# 			<CdgItem>
# 				<TpoCodigo>INT1</TpoCodigo>
# 				<VlrCodigo>E0228500</VlrCodigo>
# 			</CdgItem>
# 			<CdgItem>
# 				<TpoCodigo>EAN13</TpoCodigo>
# 				<VlrCodigo>3474630349308</VlrCodigo>
# 			</CdgItem>
# 			<NmbItem>FASHION WORK 12, 400 ML</NmbItem>
# 			<QtyItem>1</QtyItem>
# 			<UnmdItem>UN</UnmdItem>
# 			<PrcItem>9490</PrcItem>
# 			<MontoItem>9490</MontoItem>
# 		</Detalle>
# 		<Detalle>
# 			<NroLinDet>3</NroLinDet>
# 			<CdgItem>
# 				<TpoCodigo>INT1</TpoCodigo>
# 				<VlrCodigo>P1007900</VlrCodigo>
# 			</CdgItem>
# 			<CdgItem>
# 				<TpoCodigo>EAN13</TpoCodigo>
# 				<VlrCodigo>884486200020</VlrCodigo>
# 			</CdgItem>
# 			<NmbItem>RK SEQ 08 GOLD IRIDESCENT 08GI LG0</NmbItem>
# 			<QtyItem>6</QtyItem>
# 			<UnmdItem>UN</UnmdItem>
# 			<PrcItem>5690</PrcItem>
# 			<MontoItem>34140</MontoItem>
# 		</Detalle>
# 		<Detalle>
# 			<NroLinDet>4</NroLinDet>
# 			<CdgItem>
# 				<TpoCodigo>INT1</TpoCodigo>
# 				<VlrCodigo>P1043600</VlrCodigo>
# 			</CdgItem>
# 			<CdgItem>
# 				<TpoCodigo>EAN13</TpoCodigo>
# 				<VlrCodigo>884486210678</VlrCodigo>
# 			</CdgItem>
# 			<NmbItem>RK BLDIDL HIGH LIFT NAT ASH LG0</NmbItem>
# 			<QtyItem>2</QtyItem>
# 			<UnmdItem>UN</UnmdItem>
# 			<PrcItem>3990</PrcItem>
# 			<MontoItem>7980</MontoItem>
# 		</Detalle>
# 		<Detalle>
# 			<NroLinDet>5</NroLinDet>
# 			<CdgItem>
# 				<TpoCodigo>INT1</TpoCodigo>
# 				<VlrCodigo>P1043900</VlrCodigo>
# 			</CdgItem>
# 			<CdgItem>
# 				<TpoCodigo>EAN13</TpoCodigo>
# 				<VlrCodigo>884486210685</VlrCodigo>
# 			</CdgItem>
# 			<NmbItem>RK BLDIDL HIGH LIFT ASH BLUE LG0</NmbItem>
# 			<QtyItem>4</QtyItem>
# 			<UnmdItem>UN</UnmdItem>
# 			<PrcItem>3990</PrcItem>
# 			<MontoItem>15960</MontoItem>
# 		</Detalle>
# 		<Detalle>
# 			<NroLinDet>6</NroLinDet>
# 			<CdgItem>
# 				<TpoCodigo>INT1</TpoCodigo>
# 				<VlrCodigo>P1044400</VlrCodigo>
# 			</CdgItem>
# 			<CdgItem>
# 				<TpoCodigo>EAN13</TpoCodigo>
# 				<VlrCodigo>884486210708</VlrCodigo>
# 			</CdgItem>
# 			<NmbItem>RK BLDIDL HIGH LIFT PEARL LG0</NmbItem>
# 			<QtyItem>2</QtyItem>
# 			<UnmdItem>UN</UnmdItem>
# 			<PrcItem>3990</PrcItem>
# 			<MontoItem>7980</MontoItem>
# 		</Detalle>
# 		<Detalle>
# 			<NroLinDet>7</NroLinDet>
# 			<CdgItem>
# 				<TpoCodigo>INT1</TpoCodigo>
# 				<VlrCodigo>P1131400</VlrCodigo>
# 			</CdgItem>
# 			<CdgItem>
# 				<TpoCodigo>EAN13</TpoCodigo>
# 				<VlrCodigo>884486235411</VlrCodigo>
# 			</CdgItem>
# 			<NmbItem>RK CURV RINGLET 180ML RENO</NmbItem>
# 			<QtyItem>1</QtyItem>
# 			<UnmdItem>UN</UnmdItem>
# 			<PrcItem>12285</PrcItem>
# 			<MontoItem>12285</MontoItem>
# 		</Detalle>
# 		<Detalle>
# 			<NroLinDet>8</NroLinDet>
# 			<CdgItem>
# 				<TpoCodigo>INT1</TpoCodigo>
# 				<VlrCodigo>P1297900</VlrCodigo>
# 			</CdgItem>
# 			<CdgItem>
# 				<TpoCodigo>EAN13</TpoCodigo>
# 				<VlrCodigo>884486288295</VlrCodigo>
# 			</CdgItem>
# 			<NmbItem>RK ASOFT MEGAMASK 200ML V034</NmbItem>
# 			<QtyItem>2</QtyItem>
# 			<UnmdItem>UN</UnmdItem>
# 			<PrcItem>18435</PrcItem>
# 			<MontoItem>36870</MontoItem>
# 		</Detalle>
# 		<Detalle>
# 			<NroLinDet>9</NroLinDet>
# 			<CdgItem>
# 				<TpoCodigo>INT1</TpoCodigo>
# 				<VlrCodigo>P1341100</VlrCodigo>
# 			</CdgItem>
# 			<CdgItem>
# 				<TpoCodigo>EAN13</TpoCodigo>
# 				<VlrCodigo>884486301222</VlrCodigo>
# 			</CdgItem>
# 			<NmbItem>RK PH STEP 2 RESTORATIVE LTR V805</NmbItem>
# 			<QtyItem>2</QtyItem>
# 			<UnmdItem>UN</UnmdItem>
# 			<PrcItem>63000</PrcItem>
# 			<MontoItem>126000</MontoItem>
# 		</Detalle>
# 		<Detalle>
# 			<NroLinDet>10</NroLinDet>
# 			<CdgItem>
# 				<TpoCodigo>INT1</TpoCodigo>
# 				<VlrCodigo>P1428700</VlrCodigo>
# 			</CdgItem>
# 			<CdgItem>
# 				<TpoCodigo>EAN13</TpoCodigo>
# 				<VlrCodigo>884486337665</VlrCodigo>
# 			</CdgItem>
# 			<NmbItem>RK CM HAIR CLNS CRM LTR V805</NmbItem>
# 			<QtyItem>1</QtyItem>
# 			<UnmdItem>UN</UnmdItem>
# 			<PrcItem>19990</PrcItem>
# 			<MontoItem>19990</MontoItem>
# 		</Detalle>
# 		<Detalle>
# 			<NroLinDet>11</NroLinDet>
# 			<CdgItem>
# 				<TpoCodigo>INT1</TpoCodigo>
# 				<VlrCodigo>P1444400</VlrCodigo>
# 			</CdgItem>
# 			<CdgItem>
# 				<TpoCodigo>EAN13</TpoCodigo>
# 				<VlrCodigo>884486341518</VlrCodigo>
# 			</CdgItem>
# 			<NmbItem>RK BREW MANEUVER 100ML V805</NmbItem>
# 			<QtyItem>3</QtyItem>
# 			<UnmdItem>UN</UnmdItem>
# 			<PrcItem>9490</PrcItem>
# 			<MontoItem>28470</MontoItem>
# 		</Detalle>
# 		<Detalle>
# 			<NroLinDet>12</NroLinDet>
# 			<CdgItem>
# 				<TpoCodigo>INT1</TpoCodigo>
# 				<VlrCodigo>P1540800</VlrCodigo>
# 			</CdgItem>
# 			<CdgItem>
# 				<TpoCodigo>EAN13</TpoCodigo>
# 				<VlrCodigo>743877066686</VlrCodigo>
# 			</CdgItem>
# 			<NmbItem>RK SEQ 08N MOJAVE</NmbItem>
# 			<QtyItem>6</QtyItem>
# 			<UnmdItem>UN</UnmdItem>
# 			<PrcItem>5690</PrcItem>
# 			<MontoItem>34140</MontoItem>
# 		</Detalle>
# 		<Detalle>
# 			<NroLinDet>13</NroLinDet>
# 			<CdgItem>
# 				<TpoCodigo>INT1</TpoCodigo>
# 				<VlrCodigo>P1631000</VlrCodigo>
# 			</CdgItem>
# 			<CdgItem>
# 				<TpoCodigo>EAN13</TpoCodigo>
# 				<VlrCodigo>884486389282</VlrCodigo>
# 			</CdgItem>
# 			<NmbItem>RK SEQ 08NA VOLCANIC 2OZ V315</NmbItem>
# 			<QtyItem>6</QtyItem>
# 			<UnmdItem>UN</UnmdItem>
# 			<PrcItem>5690</PrcItem>
# 			<MontoItem>34140</MontoItem>
# 		</Detalle>
# 		<Detalle>
# 			<NroLinDet>14</NroLinDet>
# 			<CdgItem>
# 				<TpoCodigo>INT1</TpoCodigo>
# 				<VlrCodigo>P1631200</VlrCodigo>
# 			</CdgItem>
# 			<CdgItem>
# 				<TpoCodigo>EAN13</TpoCodigo>
# 				<VlrCodigo>884486389305</VlrCodigo>
# 			</CdgItem>
# 			<NmbItem>RK SEQ 06NA GRANITE 60ML V315</NmbItem>
# 			<QtyItem>6</QtyItem>
# 			<UnmdItem>UN</UnmdItem>
# 			<PrcItem>5690</PrcItem>
# 			<MontoItem>34140</MontoItem>
# 		</Detalle>
# 		<Referencia>
# 			<NroLinRef>1</NroLinRef>
# 			<TpoDocRef>801</TpoDocRef>
# 			<FolioRef>9990048353</FolioRef>
# 			<FchRef>2020-04-17</FchRef>
# 		</Referencia>
# <TED version="1.0"><DD><RE>79693930-3</RE><TD>33</TD><F>2248191</F><FE>2020-04-21</FE><RR>76319854-5</RR><RSR>SALONES DE BELLEZA LA BANQUETA LTDA</RSR><MNT>502126</MNT><IT1>PROCESSING SOLUTION 1 LT</IT1><CAF version="1.0"><DA><RE>79693930-3</RE><RS>L OREAL CHILE S A</RS><TD>33</TD><RNG><D>2224298</D><H>2249297</H></RNG><FA>2019-12-18</FA><RSAPK><M>zl4motCJD//UTxkzYUMJS/Xkl4jAl1qkc+quHbHvUMKkOV/jVpi7vNIhaSk9jxGD9wwjqCEnML0C41I9HSz9YQ==</M><E>Aw==</E></RSAPK><IDK>300</IDK></DA><FRMA algoritmo="SHA1withRSA">b5cGesFO9CJ/3kfuhhjOd3XHrk6Fw/5s5ZkIk4c+YnbbgXReSJ+444YqO1RtRQJVjIE9LprBA20xbpLbRZ9bWg==</FRMA></CAF><TSTED>2020-04-21T16:19:12</TSTED></DD><FRMT algoritmo="SHA1withRSA">eOZlUGRaZODg5hwwoTJksd0sX114Fc5tawXYbOJ/HB9ST6lzVCmgR73/SqQkpYhYnLJfmQ+70nm8
# K6Du/vmHWw==
# </FRMT></TED>
# <TmstFirma>2020-04-21T16:19:12</TmstFirma>
# </Documento>
# <Signature xmlns="http://www.w3.org/2000/09/xmldsig#">
#   <SignedInfo>
#     <CanonicalizationMethod Algorithm="http://www.w3.org/TR/2001/REC-xml-c14n-20010315" />
#     <SignatureMethod Algorithm="http://www.w3.org/2000/09/xmldsig#rsa-sha1" />
#     <Reference URI="#S20200421T033F0002248191">
#       <DigestMethod Algorithm="http://www.w3.org/2000/09/xmldsig#sha1" />
#       <DigestValue>EO+LGtJVXLLCwPv3Fudsfib5tho=</DigestValue>
#     </Reference>
#   </SignedInfo>
#   <SignatureValue>
#     JrYcHTPnzx/OB4sGQVsXq2BMWbIMZ4ASpSTkXOAtUHg6nALXe1/2ZtyXjcd9oOVH
#     7iwAr4YWFknbxRQ9tu0eE9xyFZg1JJqPTVcdheDDskYuj7KHat4nVci0uihefKjb
#     V6aedJjq6UIGt4dggF9TWMhCa9zpyNz91Y/ybw+ZUD8=
#   </SignatureValue>
#   <KeyInfo>
#     <KeyValue>
#       <RSAKeyValue>
#         <Modulus>
#           tBDXxxrCuyY4bCQqP6YUqMmSVdxGlzwNsMmJ0jewreeAsoZTdfrxLrZWHoJccuwe
#           YCBMi52hbIlY0AZq3pAibSSS4/J12AIHKu5cErF+SiNWwSBh5HqtyawSfjwQHttO
#           UTHR+xt1Xu7TPJpghAxzZY36O2f3PWDL9Jnl6MppwiE=
#         </Modulus>
#         <Exponent>AQAB</Exponent>
#       </RSAKeyValue>
#     </KeyValue>
#     <X509Data>
#
#       <X509Certificate>
#         MIIGdjCCBV6gAwIBAgIKJbWK2wAAAA9XZDANBgkqhkiG9w0BAQUFADCB0jELMAkG
#         A1UEBhMCQ0wxHTAbBgNVBAgTFFJlZ2lvbiBNZXRyb3BvbGl0YW5hMREwDwYDVQQH
#         EwhTYW50aWFnbzEUMBIGA1UEChMLRS1DRVJUQ0hJTEUxIDAeBgNVBAsTF0F1dG9y
#         aWRhZCBDZXJ0aWZpY2Fkb3JhMTAwLgYDVQQDEydFLUNFUlRDSElMRSBDQSBGSVJN
#         QSBFTEVDVFJPTklDQSBTSU1QTEUxJzAlBgkqhkiG9w0BCQEWGHNjbGllbnRlc0Bl
#         LWNlcnRjaGlsZS5jbDAeFw0xOTEwMjQxMzU1MzNaFw0yMjEwMjMxMzU1MzNaMIH3
#         MQswCQYDVQQGEwJDTDEqMCgGA1UECAwhUkVHScOTTiBNRVRST1BPTElUQU5BIERF
#         IFNBTlRJQUdPMREwDwYDVQQHEwhTYW50aWFnbzEYMBYGA1UEChMPTE9SRUFMIENI
#         SUxFIFNBMTMwMQYDVQQLEypWRU5UQSBBTCBQT1IgTUFZT1IgQVJUSUNVTE9TIERF
#         IFBFUkZVTUVSSUExKjAoBgNVBAMTIUFMRVhBTkRFUiBCVURZIFZJTExBUlJPRUwg
#         SEVSRURJQTEuMCwGCSqGSIb3DQEJARYfQUxFWEFOREVSLlZJTExBUlJPRUxATE9S
#         RUFMLkNPTTCBnzANBgkqhkiG9w0BAQEFAAOBjQAwgYkCgYEAtBDXxxrCuyY4bCQq
#         P6YUqMmSVdxGlzwNsMmJ0jewreeAsoZTdfrxLrZWHoJccuweYCBMi52hbIlY0AZq
#         3pAibSSS4/J12AIHKu5cErF+SiNWwSBh5HqtyawSfjwQHttOUTHR+xt1Xu7TPJpg
#         hAxzZY36O2f3PWDL9Jnl6MppwiECAwEAAaOCAqkwggKlMIIBTwYDVR0gBIIBRjCC
#         AUIwggE+BggrBgEEAcNSBTCCATAwLQYIKwYBBQUHAgEWIWh0dHA6Ly93d3cuZS1j
#         ZXJ0Y2hpbGUuY2wvQ1BTLmh0bTCB/gYIKwYBBQUHAgIwgfEege4ARQBsACAAcgBl
#         AHMAcABvAG4AZABlAHIAIABlAHMAdABlACAAZgBvAHIAbQB1AGwAYQByAGkAbwAg
#         AGUAcwAgAHUAbgAgAHIAZQBxAHUAaQBzAGkAdABvACAAaQBuAGQAaQBzAHAAZQBu
#         AHMAYQBiAGwAZQAgAHAAYQByAGEAIABkAGEAcgAgAGkAbgBpAGMAaQBvACAAYQBs
#         ACAAcAByAG8AYwBlAHMAbwAgAGQAZQAgAGMAZQByAHQAaQBmAGkAYwBhAGMAaQDz
#         AG4ALgAgAFAAbwBzAHQAZQByAGkAbwByAG0AZQBuAHQAZQAsMB0GA1UdDgQWBBSB
#         abHazBT7QG4z0IJ0Ymp1FNTtzjALBgNVHQ8EBAMCBPAwIwYDVR0RBBwwGqAYBggr
#         BgEEAcEBAaAMFgoxMDU4NjIzNy03MB8GA1UdIwQYMBaAFHjhPp/SErN6PI3NMA5T
#         s0MpB7NVMD4GA1UdHwQ3MDUwM6AxoC+GLWh0dHA6Ly9jcmwuZS1jZXJ0Y2hpbGUu
#         Y2wvZWNlcnRjaGlsZWNhRkVTLmNybDA6BggrBgEFBQcBAQQuMCwwKgYIKwYBBQUH
#         MAGGHmh0dHA6Ly9vY3NwLmVjZXJ0Y2hpbGUuY2wvb2NzcDA9BgkrBgEEAYI3FQcE
#         MDAuBiYrBgEEAYI3FQiC3IMvhZOMZoXVnReC4twnge/sPGGBy54UhqiCWAIBZAIB
#         BDAjBgNVHRIEHDAaoBgGCCsGAQQBwQECoAwWCjk2OTI4MTgwLTUwDQYJKoZIhvcN
#         AQEFBQADggEBAJEZOTg+IJ8PYy/ivvlHOOxzazN81XfihZ3Bk/hmyOpsu9bQgDYO
#         gmAdyh2yobL4Qrntknfzu2rJSAaqV0/W2P5ut5FrhUslv6t+sFDXdUAtHlanlLIL
#         ccfDunt0vzMAhykE3nY/zslKhU6DYpTY0u5PFgdrs7QjFzRebYjM1uYCoV47Me+p
#         zkrKRLU/bv1KA6rX4xeK+B7PwOAC4qd31z0VDXqIhQRPO5Srou0zUDUbQz5IgMFJ
#         QjBUPAwpaDYXk9zmufv5Q4cwUiBUqvbAO9eJB5wqGkUfjko2eXmHVNdoiyGWc1fQ
#         Rm6FZUYF7KFQHza2YIbAFZdG5bUuDcfPBKU=
#       </X509Certificate>
#     </X509Data>
#   </KeyInfo>
# </Signature>
#
#
# </DTE>
#
# </SetDTE>
# <Signature xmlns="http://www.w3.org/2000/09/xmldsig#">
#   <SignedInfo>
#     <CanonicalizationMethod Algorithm="http://www.w3.org/TR/2001/REC-xml-c14n-20010315" />
#     <SignatureMethod Algorithm="http://www.w3.org/2000/09/xmldsig#rsa-sha1" />
#     <Reference URI="#EDTE46735916D328634650">
#       <DigestMethod Algorithm="http://www.w3.org/2000/09/xmldsig#sha1" />
#       <DigestValue>S04cy39NfDS/S3ic5A2pZzwnTZg=</DigestValue>
#     </Reference>
#   </SignedInfo>
#   <SignatureValue>
#     LVYHxYD14J2K4cJ+hPEqqu3RA8kDUaW3utO6JTh06lfduerxWHHcwXqhmRDYs3yE
#     +lCXN9Z+ASkLm76sUTy/XIG/V+geu70EsuxBkdlmHsFGseOuytehcavh72NjJVH0
#     cNUdHfkoxVz9jMiFWTWB4wiPUjc6Z9+1zQNVXieHAvc=
#   </SignatureValue>
#   <KeyInfo>
#     <KeyValue>
#       <RSAKeyValue>
#         <Modulus>
#           tBDXxxrCuyY4bCQqP6YUqMmSVdxGlzwNsMmJ0jewreeAsoZTdfrxLrZWHoJccuwe
#           YCBMi52hbIlY0AZq3pAibSSS4/J12AIHKu5cErF+SiNWwSBh5HqtyawSfjwQHttO
#           UTHR+xt1Xu7TPJpghAxzZY36O2f3PWDL9Jnl6MppwiE=
#         </Modulus>
#         <Exponent>AQAB</Exponent>
#       </RSAKeyValue>
#     </KeyValue>
#     <X509Data>
#
#       <X509Certificate>
#         MIIGdjCCBV6gAwIBAgIKJbWK2wAAAA9XZDANBgkqhkiG9w0BAQUFADCB0jELMAkG
#         A1UEBhMCQ0wxHTAbBgNVBAgTFFJlZ2lvbiBNZXRyb3BvbGl0YW5hMREwDwYDVQQH
#         EwhTYW50aWFnbzEUMBIGA1UEChMLRS1DRVJUQ0hJTEUxIDAeBgNVBAsTF0F1dG9y
#         aWRhZCBDZXJ0aWZpY2Fkb3JhMTAwLgYDVQQDEydFLUNFUlRDSElMRSBDQSBGSVJN
#         QSBFTEVDVFJPTklDQSBTSU1QTEUxJzAlBgkqhkiG9w0BCQEWGHNjbGllbnRlc0Bl
#         LWNlcnRjaGlsZS5jbDAeFw0xOTEwMjQxMzU1MzNaFw0yMjEwMjMxMzU1MzNaMIH3
#         MQswCQYDVQQGEwJDTDEqMCgGA1UECAwhUkVHScOTTiBNRVRST1BPTElUQU5BIERF
#         IFNBTlRJQUdPMREwDwYDVQQHEwhTYW50aWFnbzEYMBYGA1UEChMPTE9SRUFMIENI
#         SUxFIFNBMTMwMQYDVQQLEypWRU5UQSBBTCBQT1IgTUFZT1IgQVJUSUNVTE9TIERF
#         IFBFUkZVTUVSSUExKjAoBgNVBAMTIUFMRVhBTkRFUiBCVURZIFZJTExBUlJPRUwg
#         SEVSRURJQTEuMCwGCSqGSIb3DQEJARYfQUxFWEFOREVSLlZJTExBUlJPRUxATE9S
#         RUFMLkNPTTCBnzANBgkqhkiG9w0BAQEFAAOBjQAwgYkCgYEAtBDXxxrCuyY4bCQq
#         P6YUqMmSVdxGlzwNsMmJ0jewreeAsoZTdfrxLrZWHoJccuweYCBMi52hbIlY0AZq
#         3pAibSSS4/J12AIHKu5cErF+SiNWwSBh5HqtyawSfjwQHttOUTHR+xt1Xu7TPJpg
#         hAxzZY36O2f3PWDL9Jnl6MppwiECAwEAAaOCAqkwggKlMIIBTwYDVR0gBIIBRjCC
#         AUIwggE+BggrBgEEAcNSBTCCATAwLQYIKwYBBQUHAgEWIWh0dHA6Ly93d3cuZS1j
#         ZXJ0Y2hpbGUuY2wvQ1BTLmh0bTCB/gYIKwYBBQUHAgIwgfEege4ARQBsACAAcgBl
#         AHMAcABvAG4AZABlAHIAIABlAHMAdABlACAAZgBvAHIAbQB1AGwAYQByAGkAbwAg
#         AGUAcwAgAHUAbgAgAHIAZQBxAHUAaQBzAGkAdABvACAAaQBuAGQAaQBzAHAAZQBu
#         AHMAYQBiAGwAZQAgAHAAYQByAGEAIABkAGEAcgAgAGkAbgBpAGMAaQBvACAAYQBs
#         ACAAcAByAG8AYwBlAHMAbwAgAGQAZQAgAGMAZQByAHQAaQBmAGkAYwBhAGMAaQDz
#         AG4ALgAgAFAAbwBzAHQAZQByAGkAbwByAG0AZQBuAHQAZQAsMB0GA1UdDgQWBBSB
#         abHazBT7QG4z0IJ0Ymp1FNTtzjALBgNVHQ8EBAMCBPAwIwYDVR0RBBwwGqAYBggr
#         BgEEAcEBAaAMFgoxMDU4NjIzNy03MB8GA1UdIwQYMBaAFHjhPp/SErN6PI3NMA5T
#         s0MpB7NVMD4GA1UdHwQ3MDUwM6AxoC+GLWh0dHA6Ly9jcmwuZS1jZXJ0Y2hpbGUu
#         Y2wvZWNlcnRjaGlsZWNhRkVTLmNybDA6BggrBgEFBQcBAQQuMCwwKgYIKwYBBQUH
#         MAGGHmh0dHA6Ly9vY3NwLmVjZXJ0Y2hpbGUuY2wvb2NzcDA9BgkrBgEEAYI3FQcE
#         MDAuBiYrBgEEAYI3FQiC3IMvhZOMZoXVnReC4twnge/sPGGBy54UhqiCWAIBZAIB
#         BDAjBgNVHRIEHDAaoBgGCCsGAQQBwQECoAwWCjk2OTI4MTgwLTUwDQYJKoZIhvcN
#         AQEFBQADggEBAJEZOTg+IJ8PYy/ivvlHOOxzazN81XfihZ3Bk/hmyOpsu9bQgDYO
#         gmAdyh2yobL4Qrntknfzu2rJSAaqV0/W2P5ut5FrhUslv6t+sFDXdUAtHlanlLIL
#         ccfDunt0vzMAhykE3nY/zslKhU6DYpTY0u5PFgdrs7QjFzRebYjM1uYCoV47Me+p
#         zkrKRLU/bv1KA6rX4xeK+B7PwOAC4qd31z0VDXqIhQRPO5Srou0zUDUbQz5IgMFJ
#         QjBUPAwpaDYXk9zmufv5Q4cwUiBUqvbAO9eJB5wqGkUfjko2eXmHVNdoiyGWc1fQ
#         Rm6FZUYF7KFQHza2YIbAFZdG5bUuDcfPBKU=
#       </X509Certificate>
#     </X509Data>
#   </KeyInfo>
# </Signature></EnvioDTE>

# %%
print(texto)
# Out:
# <?xml version="1.0" encoding="ISO-8859-1"?>
# <EnvioDTE version="1.0" xmlns="http://www.sii.cl/SiiDte" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.sii.cl/SiiDte EnvioDTE_v10.xsd">
# <SetDTE ID="EDTE46735916D328634650">
# <Caratula version="1.0">
# <RutEmisor>79693930-3</RutEmisor>
# <RutEnvia>10586237-7</RutEnvia>
# <RutReceptor>76319854-5</RutReceptor>
# <FchResol>2006-01-05</FchResol>
# <NroResol>1</NroResol>
# <TmstFirmaEnv>2020-04-21T15:22:26</TmstFirmaEnv>
# <SubTotDTE>
# <TpoDTE>33</TpoDTE>
# <NroDTE>1</NroDTE>
# </SubTotDTE>
# </Caratula>
# <DTE version="1.0" xmlns="http://www.sii.cl/SiiDte">
# <Documento ID="S20200421T033F0002248191">
# <Encabezado>
# <IdDoc>
# <TipoDTE>33</TipoDTE>
# 2248191
# <FchEmis>2020-04-21</FchEmis>
# <FchVenc>2020-06-20</FchVenc>
# </IdDoc>
# <Emisor>
# <RUTEmisor>79693930-3</RUTEmisor>
# <RznSoc>L OREAL CHILE S A</RznSoc>
# <GiroEmis>Distribucion productos cosmeticos y capilares</GiroEmis>
# <Acteco>513930</Acteco>
# <DirOrigen>Apoquindo 3885 piso 2</DirOrigen>
# <CmnaOrigen>LAS CONDES</CmnaOrigen>
# <CiudadOrigen>SANTIAGO</CiudadOrigen>
# <CdgVendedor>;;</CdgVendedor>
# </Emisor>
# <Receptor>
# <RUTRecep>76319854-5</RUTRecep>
# <CdgIntRecep>0000111946</CdgIntRecep>
# <RznSocRecep>SALONES DE BELLEZA LA BANQUETA LTDA</RznSocRecep>
# <GiroRecep>SALON DE BELLEZA</GiroRecep>
# <DirRecep>PRESIDENTE RIESCO 3160</DirRecep>
# <CmnaRecep>LAS CONDES</CmnaRecep>
# <CiudadRecep>SANTIAGO</CiudadRecep>
# <DirPostal>PRESIDENTE RIESCO 3160</DirPostal>
# <CmnaPostal>LAS CONDES</CmnaPostal>
# </Receptor>
# <Totales>
# <MntNeto>421955</MntNeto>
# <TasaIVA>19.00</TasaIVA>
# <IVA>80171</IVA>
# <MntTotal>502126</MntTotal>
# </Totales>
# </Encabezado>
# <Detalle>
# <NroLinDet>1</NroLinDet>
# <CdgItem>
# <TpoCodigo>INT1</TpoCodigo>
# <VlrCodigo>59451801</VlrCodigo>
# </CdgItem>
# <CdgItem>
# <TpoCodigo>EAN13</TpoCodigo>
# <VlrCodigo>743877066945</VlrCodigo>
# </CdgItem>
# <NmbItem>PROCESSING SOLUTION 1 LT</NmbItem>
# <QtyItem>3</QtyItem>
# <UnmdItem>UN</UnmdItem>
# <PrcItem>6790</PrcItem>
# <MontoItem>20370</MontoItem>
# </Detalle>
# <Detalle>
# <NroLinDet>2</NroLinDet>
# <CdgItem>
# <TpoCodigo>INT1</TpoCodigo>
# <VlrCodigo>E0228500</VlrCodigo>
# </CdgItem>
# <CdgItem>
# <TpoCodigo>EAN13</TpoCodigo>
# <VlrCodigo>3474630349308</VlrCodigo>
# </CdgItem>
# <NmbItem>FASHION WORK 12, 400 ML</NmbItem>
# <QtyItem>1</QtyItem>
# <UnmdItem>UN</UnmdItem>
# <PrcItem>9490</PrcItem>
# <MontoItem>9490</MontoItem>
# </Detalle>
# <Detalle>
# <NroLinDet>3</NroLinDet>
# <CdgItem>
# <TpoCodigo>INT1</TpoCodigo>
# <VlrCodigo>P1007900</VlrCodigo>
# </CdgItem>
# <CdgItem>
# <TpoCodigo>EAN13</TpoCodigo>
# <VlrCodigo>884486200020</VlrCodigo>
# </CdgItem>
# <NmbItem>RK SEQ 08 GOLD IRIDESCENT 08GI LG0</NmbItem>
# <QtyItem>6</QtyItem>
# <UnmdItem>UN</UnmdItem>
# <PrcItem>5690</PrcItem>
# <MontoItem>34140</MontoItem>
# </Detalle>
# <Detalle>
# <NroLinDet>4</NroLinDet>
# <CdgItem>
# <TpoCodigo>INT1</TpoCodigo>
# <VlrCodigo>P1043600</VlrCodigo>
# </CdgItem>
# <CdgItem>
# <TpoCodigo>EAN13</TpoCodigo>
# <VlrCodigo>884486210678</VlrCodigo>
# </CdgItem>
# <NmbItem>RK BLDIDL HIGH LIFT NAT ASH LG0</NmbItem>
# <QtyItem>2</QtyItem>
# <UnmdItem>UN</UnmdItem>
# <PrcItem>3990</PrcItem>
# <MontoItem>7980</MontoItem>
# </Detalle>
# <Detalle>
# <NroLinDet>5</NroLinDet>
# <CdgItem>
# <TpoCodigo>INT1</TpoCodigo>
# <VlrCodigo>P1043900</VlrCodigo>
# </CdgItem>
# <CdgItem>
# <TpoCodigo>EAN13</TpoCodigo>
# <VlrCodigo>884486210685</VlrCodigo>
# </CdgItem>
# <NmbItem>RK BLDIDL HIGH LIFT ASH BLUE LG0</NmbItem>
# <QtyItem>4</QtyItem>
# <UnmdItem>UN</UnmdItem>
# <PrcItem>3990</PrcItem>
# <MontoItem>15960</MontoItem>
# </Detalle>
# <Detalle>
# <NroLinDet>6</NroLinDet>
# <CdgItem>
# <TpoCodigo>INT1</TpoCodigo>
# <VlrCodigo>P1044400</VlrCodigo>
# </CdgItem>
# <CdgItem>
# <TpoCodigo>EAN13</TpoCodigo>
# <VlrCodigo>884486210708</VlrCodigo>
# </CdgItem>
# <NmbItem>RK BLDIDL HIGH LIFT PEARL LG0</NmbItem>
# <QtyItem>2</QtyItem>
# <UnmdItem>UN</UnmdItem>
# <PrcItem>3990</PrcItem>
# <MontoItem>7980</MontoItem>
# </Detalle>
# <Detalle>
# <NroLinDet>7</NroLinDet>
# <CdgItem>
# <TpoCodigo>INT1</TpoCodigo>
# <VlrCodigo>P1131400</VlrCodigo>
# </CdgItem>
# <CdgItem>
# <TpoCodigo>EAN13</TpoCodigo>
# <VlrCodigo>884486235411</VlrCodigo>
# </CdgItem>
# <NmbItem>RK CURV RINGLET 180ML RENO</NmbItem>
# <QtyItem>1</QtyItem>
# <UnmdItem>UN</UnmdItem>
# <PrcItem>12285</PrcItem>
# <MontoItem>12285</MontoItem>
# </Detalle>
# <Detalle>
# <NroLinDet>8</NroLinDet>
# <CdgItem>
# <TpoCodigo>INT1</TpoCodigo>
# <VlrCodigo>P1297900</VlrCodigo>
# </CdgItem>
# <CdgItem>
# <TpoCodigo>EAN13</TpoCodigo>
# <VlrCodigo>884486288295</VlrCodigo>
# </CdgItem>
# <NmbItem>RK ASOFT MEGAMASK 200ML V034</NmbItem>
# <QtyItem>2</QtyItem>
# <UnmdItem>UN</UnmdItem>
# <PrcItem>18435</PrcItem>
# <MontoItem>36870</MontoItem>
# </Detalle>
# <Detalle>
# <NroLinDet>9</NroLinDet>
# <CdgItem>
# <TpoCodigo>INT1</TpoCodigo>
# <VlrCodigo>P1341100</VlrCodigo>
# </CdgItem>
# <CdgItem>
# <TpoCodigo>EAN13</TpoCodigo>
# <VlrCodigo>884486301222</VlrCodigo>
# </CdgItem>
# <NmbItem>RK PH STEP 2 RESTORATIVE LTR V805</NmbItem>
# <QtyItem>2</QtyItem>
# <UnmdItem>UN</UnmdItem>
# <PrcItem>63000</PrcItem>
# <MontoItem>126000</MontoItem>
# </Detalle>
# <Detalle>
# <NroLinDet>10</NroLinDet>
# <CdgItem>
# <TpoCodigo>INT1</TpoCodigo>
# <VlrCodigo>P1428700</VlrCodigo>
# </CdgItem>
# <CdgItem>
# <TpoCodigo>EAN13</TpoCodigo>
# <VlrCodigo>884486337665</VlrCodigo>
# </CdgItem>
# <NmbItem>RK CM HAIR CLNS CRM LTR V805</NmbItem>
# <QtyItem>1</QtyItem>
# <UnmdItem>UN</UnmdItem>
# <PrcItem>19990</PrcItem>
# <MontoItem>19990</MontoItem>
# </Detalle>
# <Detalle>
# <NroLinDet>11</NroLinDet>
# <CdgItem>
# <TpoCodigo>INT1</TpoCodigo>
# <VlrCodigo>P1444400</VlrCodigo>
# </CdgItem>
# <CdgItem>
# <TpoCodigo>EAN13</TpoCodigo>
# <VlrCodigo>884486341518</VlrCodigo>
# </CdgItem>
# <NmbItem>RK BREW MANEUVER 100ML V805</NmbItem>
# <QtyItem>3</QtyItem>
# <UnmdItem>UN</UnmdItem>
# <PrcItem>9490</PrcItem>
# <MontoItem>28470</MontoItem>
# </Detalle>
# <Detalle>
# <NroLinDet>12</NroLinDet>
# <CdgItem>
# <TpoCodigo>INT1</TpoCodigo>
# <VlrCodigo>P1540800</VlrCodigo>
# </CdgItem>
# <CdgItem>
# <TpoCodigo>EAN13</TpoCodigo>
# <VlrCodigo>743877066686</VlrCodigo>
# </CdgItem>
# <NmbItem>RK SEQ 08N MOJAVE</NmbItem>
# <QtyItem>6</QtyItem>
# <UnmdItem>UN</UnmdItem>
# <PrcItem>5690</PrcItem>
# <MontoItem>34140</MontoItem>
# </Detalle>
# <Detalle>
# <NroLinDet>13</NroLinDet>
# <CdgItem>
# <TpoCodigo>INT1</TpoCodigo>
# <VlrCodigo>P1631000</VlrCodigo>
# </CdgItem>
# <CdgItem>
# <TpoCodigo>EAN13</TpoCodigo>
# <VlrCodigo>884486389282</VlrCodigo>
# </CdgItem>
# <NmbItem>RK SEQ 08NA VOLCANIC 2OZ V315</NmbItem>
# <QtyItem>6</QtyItem>
# <UnmdItem>UN</UnmdItem>
# <PrcItem>5690</PrcItem>
# <MontoItem>34140</MontoItem>
# </Detalle>
# <Detalle>
# <NroLinDet>14</NroLinDet>
# <CdgItem>
# <TpoCodigo>INT1</TpoCodigo>
# <VlrCodigo>P1631200</VlrCodigo>
# </CdgItem>
# <CdgItem>
# <TpoCodigo>EAN13</TpoCodigo>
# <VlrCodigo>884486389305</VlrCodigo>
# </CdgItem>
# <NmbItem>RK SEQ 06NA GRANITE 60ML V315</NmbItem>
# <QtyItem>6</QtyItem>
# <UnmdItem>UN</UnmdItem>
# <PrcItem>5690</PrcItem>
# <MontoItem>34140</MontoItem>
# </Detalle>
# <Referencia>
# <NroLinRef>1</NroLinRef>
# <TpoDocRef>801</TpoDocRef>
# <FolioRef>9990048353</FolioRef>
# <FchRef>2020-04-17</FchRef>
# </Referencia>
# <TED version="1.0"><DD><RE>79693930-3</RE><TD>33</TD><F>2248191</F><FE>2020-04-21</FE><RR>76319854-5</RR><RSR>SALONES DE BELLEZA LA BANQUETA LTDA</RSR><MNT>502126</MNT><IT1>PROCESSING SOLUTION 1 LT</IT1><CAF version="1.0"><DA><RE>79693930-3</RE><RS>L OREAL CHILE S A</RS><TD>33</TD><RNG><D>2224298</D><H>2249297</H></RNG><FA>2019-12-18</FA><RSAPK><M>zl4motCJD//UTxkzYUMJS/Xkl4jAl1qkc+quHbHvUMKkOV/jVpi7vNIhaSk9jxGD9wwjqCEnML0C41I9HSz9YQ==</M><E>Aw==</E></RSAPK><IDK>300</IDK></DA><FRMA algoritmo="SHA1withRSA">b5cGesFO9CJ/3kfuhhjOd3XHrk6Fw/5s5ZkIk4c+YnbbgXReSJ+444YqO1RtRQJVjIE9LprBA20xbpLbRZ9bWg==</FRMA></CAF><TSTED>2020-04-21T16:19:12</TSTED></DD><FRMT algoritmo="SHA1withRSA">eOZlUGRaZODg5hwwoTJksd0sX114Fc5tawXYbOJ/HB9ST6lzVCmgR73/SqQkpYhYnLJfmQ+70nm8
# K6Du/vmHWw==
# </FRMT></TED>
# <TmstFirma>2020-04-21T16:19:12</TmstFirma>
# </Documento>
# <Signature xmlns="http://www.w3.org/2000/09/xmldsig#">
# <SignedInfo>
# <CanonicalizationMethod Algorithm="http://www.w3.org/TR/2001/REC-xml-c14n-20010315" />
# <SignatureMethod Algorithm="http://www.w3.org/2000/09/xmldsig#rsa-sha1" />
# <Reference URI="#S20200421T033F0002248191">
# <DigestMethod Algorithm="http://www.w3.org/2000/09/xmldsig#sha1" />
# <DigestValue>EO+LGtJVXLLCwPv3Fudsfib5tho=</DigestValue>
# </Reference>
# </SignedInfo>
# <SignatureValue>
# JrYcHTPnzx/OB4sGQVsXq2BMWbIMZ4ASpSTkXOAtUHg6nALXe1/2ZtyXjcd9oOVH
# 7iwAr4YWFknbxRQ9tu0eE9xyFZg1JJqPTVcdheDDskYuj7KHat4nVci0uihefKjb
# V6aedJjq6UIGt4dggF9TWMhCa9zpyNz91Y/ybw+ZUD8=
# </SignatureValue>
# <KeyInfo>
# <KeyValue>
# <RSAKeyValue>
# <Modulus>
# tBDXxxrCuyY4bCQqP6YUqMmSVdxGlzwNsMmJ0jewreeAsoZTdfrxLrZWHoJccuwe
# YCBMi52hbIlY0AZq3pAibSSS4/J12AIHKu5cErF+SiNWwSBh5HqtyawSfjwQHttO
# UTHR+xt1Xu7TPJpghAxzZY36O2f3PWDL9Jnl6MppwiE=
# </Modulus>
# <Exponent>AQAB</Exponent>
# </RSAKeyValue>
# </KeyValue>
# <X509Data>
# <X509Certificate>
# MIIGdjCCBV6gAwIBAgIKJbWK2wAAAA9XZDANBgkqhkiG9w0BAQUFADCB0jELMAkG
# A1UEBhMCQ0wxHTAbBgNVBAgTFFJlZ2lvbiBNZXRyb3BvbGl0YW5hMREwDwYDVQQH
# EwhTYW50aWFnbzEUMBIGA1UEChMLRS1DRVJUQ0hJTEUxIDAeBgNVBAsTF0F1dG9y
# aWRhZCBDZXJ0aWZpY2Fkb3JhMTAwLgYDVQQDEydFLUNFUlRDSElMRSBDQSBGSVJN
# QSBFTEVDVFJPTklDQSBTSU1QTEUxJzAlBgkqhkiG9w0BCQEWGHNjbGllbnRlc0Bl
# LWNlcnRjaGlsZS5jbDAeFw0xOTEwMjQxMzU1MzNaFw0yMjEwMjMxMzU1MzNaMIH3
# MQswCQYDVQQGEwJDTDEqMCgGA1UECAwhUkVHScOTTiBNRVRST1BPTElUQU5BIERF
# IFNBTlRJQUdPMREwDwYDVQQHEwhTYW50aWFnbzEYMBYGA1UEChMPTE9SRUFMIENI
# SUxFIFNBMTMwMQYDVQQLEypWRU5UQSBBTCBQT1IgTUFZT1IgQVJUSUNVTE9TIERF
# IFBFUkZVTUVSSUExKjAoBgNVBAMTIUFMRVhBTkRFUiBCVURZIFZJTExBUlJPRUwg
# SEVSRURJQTEuMCwGCSqGSIb3DQEJARYfQUxFWEFOREVSLlZJTExBUlJPRUxATE9S
# RUFMLkNPTTCBnzANBgkqhkiG9w0BAQEFAAOBjQAwgYkCgYEAtBDXxxrCuyY4bCQq
# P6YUqMmSVdxGlzwNsMmJ0jewreeAsoZTdfrxLrZWHoJccuweYCBMi52hbIlY0AZq
# 3pAibSSS4/J12AIHKu5cErF+SiNWwSBh5HqtyawSfjwQHttOUTHR+xt1Xu7TPJpg
# hAxzZY36O2f3PWDL9Jnl6MppwiECAwEAAaOCAqkwggKlMIIBTwYDVR0gBIIBRjCC
# AUIwggE+BggrBgEEAcNSBTCCATAwLQYIKwYBBQUHAgEWIWh0dHA6Ly93d3cuZS1j
# ZXJ0Y2hpbGUuY2wvQ1BTLmh0bTCB/gYIKwYBBQUHAgIwgfEege4ARQBsACAAcgBl
# AHMAcABvAG4AZABlAHIAIABlAHMAdABlACAAZgBvAHIAbQB1AGwAYQByAGkAbwAg
# AGUAcwAgAHUAbgAgAHIAZQBxAHUAaQBzAGkAdABvACAAaQBuAGQAaQBzAHAAZQBu
# AHMAYQBiAGwAZQAgAHAAYQByAGEAIABkAGEAcgAgAGkAbgBpAGMAaQBvACAAYQBs
# ACAAcAByAG8AYwBlAHMAbwAgAGQAZQAgAGMAZQByAHQAaQBmAGkAYwBhAGMAaQDz
# AG4ALgAgAFAAbwBzAHQAZQByAGkAbwByAG0AZQBuAHQAZQAsMB0GA1UdDgQWBBSB
# abHazBT7QG4z0IJ0Ymp1FNTtzjALBgNVHQ8EBAMCBPAwIwYDVR0RBBwwGqAYBggr
# BgEEAcEBAaAMFgoxMDU4NjIzNy03MB8GA1UdIwQYMBaAFHjhPp/SErN6PI3NMA5T
# s0MpB7NVMD4GA1UdHwQ3MDUwM6AxoC+GLWh0dHA6Ly9jcmwuZS1jZXJ0Y2hpbGUu
# Y2wvZWNlcnRjaGlsZWNhRkVTLmNybDA6BggrBgEFBQcBAQQuMCwwKgYIKwYBBQUH
# MAGGHmh0dHA6Ly9vY3NwLmVjZXJ0Y2hpbGUuY2wvb2NzcDA9BgkrBgEEAYI3FQcE
# MDAuBiYrBgEEAYI3FQiC3IMvhZOMZoXVnReC4twnge/sPGGBy54UhqiCWAIBZAIB
# BDAjBgNVHRIEHDAaoBgGCCsGAQQBwQECoAwWCjk2OTI4MTgwLTUwDQYJKoZIhvcN
# AQEFBQADggEBAJEZOTg+IJ8PYy/ivvlHOOxzazN81XfihZ3Bk/hmyOpsu9bQgDYO
# gmAdyh2yobL4Qrntknfzu2rJSAaqV0/W2P5ut5FrhUslv6t+sFDXdUAtHlanlLIL
# ccfDunt0vzMAhykE3nY/zslKhU6DYpTY0u5PFgdrs7QjFzRebYjM1uYCoV47Me+p
# zkrKRLU/bv1KA6rX4xeK+B7PwOAC4qd31z0VDXqIhQRPO5Srou0zUDUbQz5IgMFJ
# QjBUPAwpaDYXk9zmufv5Q4cwUiBUqvbAO9eJB5wqGkUfjko2eXmHVNdoiyGWc1fQ
# Rm6FZUYF7KFQHza2YIbAFZdG5bUuDcfPBKU=
# </X509Certificate>
# </X509Data>
# </KeyInfo>
# </Signature>
# </DTE>
# </SetDTE>
# <Signature xmlns="http://www.w3.org/2000/09/xmldsig#">
# <SignedInfo>
# <CanonicalizationMethod Algorithm="http://www.w3.org/TR/2001/REC-xml-c14n-20010315" />
# <SignatureMethod Algorithm="http://www.w3.org/2000/09/xmldsig#rsa-sha1" />
# <Reference URI="#EDTE46735916D328634650">
# <DigestMethod Algorithm="http://www.w3.org/2000/09/xmldsig#sha1" />
# <DigestValue>S04cy39NfDS/S3ic5A2pZzwnTZg=</DigestValue>
# </Reference>
# </SignedInfo>
# <SignatureValue>
# LVYHxYD14J2K4cJ+hPEqqu3RA8kDUaW3utO6JTh06lfduerxWHHcwXqhmRDYs3yE
# +lCXN9Z+ASkLm76sUTy/XIG/V+geu70EsuxBkdlmHsFGseOuytehcavh72NjJVH0
# cNUdHfkoxVz9jMiFWTWB4wiPUjc6Z9+1zQNVXieHAvc=
# </SignatureValue>
# <KeyInfo>
# <KeyValue>
# <RSAKeyValue>
# <Modulus>
# tBDXxxrCuyY4bCQqP6YUqMmSVdxGlzwNsMmJ0jewreeAsoZTdfrxLrZWHoJccuwe
# YCBMi52hbIlY0AZq3pAibSSS4/J12AIHKu5cErF+SiNWwSBh5HqtyawSfjwQHttO
# UTHR+xt1Xu7TPJpghAxzZY36O2f3PWDL9Jnl6MppwiE=
# </Modulus>
# <Exponent>AQAB</Exponent>
# </RSAKeyValue>
# </KeyValue>
# <X509Data>
# <X509Certificate>
# MIIGdjCCBV6gAwIBAgIKJbWK2wAAAA9XZDANBgkqhkiG9w0BAQUFADCB0jELMAkG
# A1UEBhMCQ0wxHTAbBgNVBAgTFFJlZ2lvbiBNZXRyb3BvbGl0YW5hMREwDwYDVQQH
# EwhTYW50aWFnbzEUMBIGA1UEChMLRS1DRVJUQ0hJTEUxIDAeBgNVBAsTF0F1dG9y
# aWRhZCBDZXJ0aWZpY2Fkb3JhMTAwLgYDVQQDEydFLUNFUlRDSElMRSBDQSBGSVJN
# QSBFTEVDVFJPTklDQSBTSU1QTEUxJzAlBgkqhkiG9w0BCQEWGHNjbGllbnRlc0Bl
# LWNlcnRjaGlsZS5jbDAeFw0xOTEwMjQxMzU1MzNaFw0yMjEwMjMxMzU1MzNaMIH3
# MQswCQYDVQQGEwJDTDEqMCgGA1UECAwhUkVHScOTTiBNRVRST1BPTElUQU5BIERF
# IFNBTlRJQUdPMREwDwYDVQQHEwhTYW50aWFnbzEYMBYGA1UEChMPTE9SRUFMIENI
# SUxFIFNBMTMwMQYDVQQLEypWRU5UQSBBTCBQT1IgTUFZT1IgQVJUSUNVTE9TIERF
# IFBFUkZVTUVSSUExKjAoBgNVBAMTIUFMRVhBTkRFUiBCVURZIFZJTExBUlJPRUwg
# SEVSRURJQTEuMCwGCSqGSIb3DQEJARYfQUxFWEFOREVSLlZJTExBUlJPRUxATE9S
# RUFMLkNPTTCBnzANBgkqhkiG9w0BAQEFAAOBjQAwgYkCgYEAtBDXxxrCuyY4bCQq
# P6YUqMmSVdxGlzwNsMmJ0jewreeAsoZTdfrxLrZWHoJccuweYCBMi52hbIlY0AZq
# 3pAibSSS4/J12AIHKu5cErF+SiNWwSBh5HqtyawSfjwQHttOUTHR+xt1Xu7TPJpg
# hAxzZY36O2f3PWDL9Jnl6MppwiECAwEAAaOCAqkwggKlMIIBTwYDVR0gBIIBRjCC
# AUIwggE+BggrBgEEAcNSBTCCATAwLQYIKwYBBQUHAgEWIWh0dHA6Ly93d3cuZS1j
# ZXJ0Y2hpbGUuY2wvQ1BTLmh0bTCB/gYIKwYBBQUHAgIwgfEege4ARQBsACAAcgBl
# AHMAcABvAG4AZABlAHIAIABlAHMAdABlACAAZgBvAHIAbQB1AGwAYQByAGkAbwAg
# AGUAcwAgAHUAbgAgAHIAZQBxAHUAaQBzAGkAdABvACAAaQBuAGQAaQBzAHAAZQBu
# AHMAYQBiAGwAZQAgAHAAYQByAGEAIABkAGEAcgAgAGkAbgBpAGMAaQBvACAAYQBs
# ACAAcAByAG8AYwBlAHMAbwAgAGQAZQAgAGMAZQByAHQAaQBmAGkAYwBhAGMAaQDz
# AG4ALgAgAFAAbwBzAHQAZQByAGkAbwByAG0AZQBuAHQAZQAsMB0GA1UdDgQWBBSB
# abHazBT7QG4z0IJ0Ymp1FNTtzjALBgNVHQ8EBAMCBPAwIwYDVR0RBBwwGqAYBggr
# BgEEAcEBAaAMFgoxMDU4NjIzNy03MB8GA1UdIwQYMBaAFHjhPp/SErN6PI3NMA5T
# s0MpB7NVMD4GA1UdHwQ3MDUwM6AxoC+GLWh0dHA6Ly9jcmwuZS1jZXJ0Y2hpbGUu
# Y2wvZWNlcnRjaGlsZWNhRkVTLmNybDA6BggrBgEFBQcBAQQuMCwwKgYIKwYBBQUH
# MAGGHmh0dHA6Ly9vY3NwLmVjZXJ0Y2hpbGUuY2wvb2NzcDA9BgkrBgEEAYI3FQcE
# MDAuBiYrBgEEAYI3FQiC3IMvhZOMZoXVnReC4twnge/sPGGBy54UhqiCWAIBZAIB
# BDAjBgNVHRIEHDAaoBgGCCsGAQQBwQECoAwWCjk2OTI4MTgwLTUwDQYJKoZIhvcN
# AQEFBQADggEBAJEZOTg+IJ8PYy/ivvlHOOxzazN81XfihZ3Bk/hmyOpsu9bQgDYO
# gmAdyh2yobL4Qrntknfzu2rJSAaqV0/W2P5ut5FrhUslv6t+sFDXdUAtHlanlLIL
# ccfDunt0vzMAhykE3nY/zslKhU6DYpTY0u5PFgdrs7QjFzRebYjM1uYCoV47Me+p
# zkrKRLU/bv1KA6rX4xeK+B7PwOAC4qd31z0VDXqIhQRPO5Srou0zUDUbQz5IgMFJ
# QjBUPAwpaDYXk9zmufv5Q4cwUiBUqvbAO9eJB5wqGkUfjko2eXmHVNdoiyGWc1fQ
# Rm6FZUYF7KFQHza2YIbAFZdG5bUuDcfPBKU=
# </X509Certificate>
# </X509Data>
# </KeyInfo>
# </Signature></EnvioDTE>

# %%
from xml.etree import cElementTree as ET
import pandas as pd

path = 'D:/Google Drive/LA BANQUETA/PEDIDOS PRODUCTOS/FACTURAS/'
file = input("Nombre del archivo: ")
archivo = open(path+file,'r')
factura = archivo.readlines()
archivo.close()

texto = ""
folio=0
fecha = ''
proveedor = ''
eans = []
codInterno = []
items = []
cantidad = []
precios = []

for i in factura:
    i=i.lstrip()
    if i[0:7] == "<Folio>":
        i= i.replace("<Folio>","")
        i= i.replace("</Folio>","")
        i = i.replace("\n","")
        folio=i
        i = i + '\n'
    if i[0:8] == "<FchRef>":
        i= i.replace("<FchRef>","")
        i= i.replace("</FchRef>","")
        i = i.replace("\n","")
        fecha=i
        i = i + '\n'
    if i[0:8] == "<RznSoc>":
        i= i.replace("<RznSoc>","")
        i= i.replace("</RznSoc>","")
        i = i.replace("\n","")
        proveedor=i
        i = i + '\n'
    
    if i[0:11] == "<VlrCodigo>":
        i = i.replace("<VlrCodigo>","")
        i = i.replace("</VlrCodigo>","")
        i = i.replace("\n","")
        if len(i) <=8:
            codInterno.append(i)
        else: 
            eans.append(i)
        i = i + '\n'
    if i[0:9] == "<NmbItem>":
        i = i.replace("<NmbItem>","")
        i = i.replace("</NmbItem>","")
        i = i.replace("\n","")
        items.append(i)
        i = i + '\n'
    if i[0:9] == "<QtyItem>":
        i = i.replace("<QtyItem>","")
        i = i.replace("</QtyItem>","")
        i = i.replace("\n","")
        cantidad.append(int(i))
        i = i + '\n'
    if i[0:9] == "<PrcItem>":
        i = i.replace("<PrcItem>","")
        i = i.replace("</PrcItem>","")
        i = i.replace("\n","")
        precios.append(int(i))
        i = i + '\n'

    texto += i
    
data = pd.DataFrame(
    {
        "EAN" : eans,
        "CodigoInterno" : codInterno,
        "Descripción" : items,
        "Cantidad" : cantidad,
        "Precio" : precios,
        "Venta":0,
        "Fecha" : fecha,
        "Factura": folio,
        "Proveedor":proveedor
    }
)
data["Venta"] = data["Precio"]*data["Cantidad"]
data.head(15)

data.to_excel(path+'{} {} - Factura {}.xlsx'.format(fecha,proveedor,folio))
# Out:
# Nombre del archivo: FCH_3322503851589392424746.xml
#               EAN CodigoInterno                          Descripción  \
# 0    743877066945      59451801             PROCESSING SOLUTION 1 LT
# 1   3474630349308      E0228500              FASHION WORK 12, 400 ML
# 2    884486013958      P0278800        EXTREME SHOT PHASE RENO 500ML
# 3    884486041852      P0425300  CHEMISTRY ALL SOFT SHOT PHASE 500ML
# 4    884486210678      P1043600      RK BLDIDL HIGH LIFT NAT ASH LG0
# 5    884486210685      P1043900     RK BLDIDL HIGH LIFT ASH BLUE LG0
# 6    884486210746      P1045500     RK BLDIDL HIGH LIFT TITANIUM LG0
# 7    884486235411      P1131400           RK CURV RINGLET 180ML RENO
# 8    884486255846      P1177400               RK SEQ GLOSS 05NW V315
# 9    884486288295      P1297900         RK ASOFT MEGAMASK 200ML V034
# 10   884486341518      P1444400          RK BREW MANEUVER 100ML V805
# 11   884486341594      P1445200           RK BREW OUTPLAY 100ML V805
# 12   884486359339      P1498400               RK CFCVF 6NA 60ML V315
# 13   743877066464      P1539200             RK SEQ 09G VANILLA CREME
# 14   743877066532      P1539600             RK SEQ 06N MORROCAN SAND
#
#     Cantidad  Precio  Venta       Fecha  Factura          Proveedor
# 0          2    6790  13580  2020-05-11  2250385  L OREAL CHILE S A
# 1          1    9490   9490  2020-05-11  2250385  L OREAL CHILE S A
# 2          1   27490  27490  2020-05-11  2250385  L OREAL CHILE S A
# 3          1   27490  27490  2020-05-11  2250385  L OREAL CHILE S A
# 4          1    3990   3990  2020-05-11  2250385  L OREAL CHILE S A
# 5          1    3990   3990  2020-05-11  2250385  L OREAL CHILE S A
# 6          5    3990  19950  2020-05-11  2250385  L OREAL CHILE S A
# 7          4   12285  49140  2020-05-11  2250385  L OREAL CHILE S A
# 8          6    5690  34140  2020-05-11  2250385  L OREAL CHILE S A
# 9          2   18435  36870  2020-05-11  2250385  L OREAL CHILE S A
# 10         6    9490  56940  2020-05-11  2250385  L OREAL CHILE S A
# 11         6    9490  56940  2020-05-11  2250385  L OREAL CHILE S A
# 12         1    4490   4490  2020-05-11  2250385  L OREAL CHILE S A
# 13        12    5690  68280  2020-05-11  2250385  L OREAL CHILE S A
# 14        12    5690  68280  2020-05-11  2250385  L OREAL CHILE S A
